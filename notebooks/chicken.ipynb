# %% [markdown]
# # Théorème Chicken McNugget
#
# Quel est le plus grand nombre de *McNuggets* qu'on ne peut pas acheter si ceux-ci sont vendus par paquets de 6, 9 et 20 ?
#
# **Remarque**  Ce problème est modélisable dans l'arithmétique de Presburger, on peut le modéliser avec Walnut qui met en œuvre les arithmétiques de Büchi qui sont plus expressives.
#
# ## 1. Décomposition
#
# On définit un prédicat `decomp(n)` qui est vrai uniquement si $n$ est décomposable, c'est-à-dire s'il existe $a$, $b$ et $c$ tels que $n = 6a + 9b + 20c$. Avec Walnut, ça donne :

# %%
def decomp "Ea,b,c n = 6*a+9*b+20*c":
# Out:
# n=(((6*a)+(9*b))+(20*c)):35 states - 5ms
#  (E a , b , c n=(((6*a)+(9*b))+(20*c))):15 states - 2ms
# Total computation time: 50ms.

# %% [markdown]
# En Walnut, tout prédicat est représenté par un automate fini déterministe. On peut visualiser cet automate lorsqu'il n'est pas trop gros.

# %%
%showme decomp
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="748pt" height="328pt"
#  viewBox="0.00 0.00 748.19 328.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 324)">
# <title>G</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-324 744.19,-324 744.19,4 -4,4"/>
# <text text-anchor="middle" x="370.1" y="-7.8" font-family="Times,serif" font-size="14.00">(n): Ea,b,c n = 6*a+9*b+20*c</text>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="black" cx="62.6" cy="-182" rx="18" ry="18"/>
# <ellipse fill="none" stroke="black" cx="62.6" cy="-182" rx="22" ry="22"/>
# <text text-anchor="middle" x="62.6" y="-178.9" font-family="Times,serif" font-size="12.00">0</text>
# </g>
# <!-- 0&#45;&gt;0 -->
# <g id="edge2" class="edge">
# <title>0&#45;&gt;0</title>
# <path fill="none" stroke="black" d="M55.28,-202.99C54.38,-213.09 56.82,-222 62.6,-222 66.3,-222 68.64,-218.34 69.6,-213.06"/>
# <polygon fill="black" stroke="black" points="73.1,-213.1 69.92,-202.99 66.1,-212.87 73.1,-213.1"/>
# <text text-anchor="middle" x="62.6" y="-225.8" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="black" cx="148.6" cy="-182" rx="18" ry="18"/>
# <text text-anchor="middle" x="148.6" y="-178.9" font-family="Times,serif" font-size="12.00">1</text>
# </g>
# <!-- 0&#45;&gt;1 -->
# <g id="edge3" class="edge">
# <title>0&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M84.8,-182C95.48,-182 108.56,-182 120.01,-182"/>
# <polygon fill="black" stroke="black" points="120.37,-185.5 130.37,-182 120.37,-178.5 120.37,-185.5"/>
# <text text-anchor="middle" x="107.6" y="-185.8" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="black" cx="230.6" cy="-218" rx="18" ry="18"/>
# <text text-anchor="middle" x="230.6" y="-214.9" font-family="Times,serif" font-size="12.00">2</text>
# </g>
# <!-- 1&#45;&gt;2 -->
# <g id="edge4" class="edge">
# <title>1&#45;&gt;2</title>
# <path fill="none" stroke="black" d="M165.41,-189.11C176.58,-194.14 191.79,-200.99 204.61,-206.75"/>
# <polygon fill="black" stroke="black" points="203.27,-209.99 213.83,-210.9 206.14,-203.61 203.27,-209.99"/>
# <text text-anchor="middle" x="189.6" y="-206.8" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 3 -->
# <g id="node4" class="node">
# <title>3</title>
# <ellipse fill="none" stroke="black" cx="312.6" cy="-164" rx="18" ry="18"/>
# <text text-anchor="middle" x="312.6" y="-160.9" font-family="Times,serif" font-size="12.00">3</text>
# </g>
# <!-- 1&#45;&gt;3 -->
# <g id="edge5" class="edge">
# <title>1&#45;&gt;3</title>
# <path fill="none" stroke="black" d="M166.63,-180.11C194.63,-177 250.64,-170.77 284.25,-167.04"/>
# <polygon fill="black" stroke="black" points="284.76,-170.5 294.31,-165.92 283.98,-163.55 284.76,-170.5"/>
# <text text-anchor="middle" x="230.6" y="-178.8" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 4 -->
# <g id="node5" class="node">
# <title>4</title>
# <ellipse fill="none" stroke="black" cx="312.6" cy="-272" rx="18" ry="18"/>
# <text text-anchor="middle" x="312.6" y="-268.9" font-family="Times,serif" font-size="12.00">4</text>
# </g>
# <!-- 2&#45;&gt;4 -->
# <g id="edge6" class="edge">
# <title>2&#45;&gt;4</title>
# <path fill="none" stroke="black" d="M245.9,-227.65C257.77,-235.67 274.88,-247.22 288.66,-256.52"/>
# <polygon fill="black" stroke="black" points="286.91,-259.55 297.15,-262.25 290.82,-253.75 286.91,-259.55"/>
# <text text-anchor="middle" x="271.6" y="-252.8" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 5 -->
# <g id="node6" class="node">
# <title>5</title>
# <ellipse fill="none" stroke="black" cx="312.6" cy="-218" rx="18" ry="18"/>
# <text text-anchor="middle" x="312.6" y="-214.9" font-family="Times,serif" font-size="12.00">5</text>
# </g>
# <!-- 2&#45;&gt;5 -->
# <g id="edge7" class="edge">
# <title>2&#45;&gt;5</title>
# <path fill="none" stroke="black" d="M248.96,-218C259.3,-218 272.66,-218 284.38,-218"/>
# <polygon fill="black" stroke="black" points="284.55,-221.5 294.55,-218 284.55,-214.5 284.55,-221.5"/>
# <text text-anchor="middle" x="271.6" y="-221.8" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 6 -->
# <g id="node7" class="node">
# <title>6</title>
# <ellipse fill="none" stroke="black" cx="398.6" cy="-176" rx="18" ry="18"/>
# <ellipse fill="none" stroke="black" cx="398.6" cy="-176" rx="22" ry="22"/>
# <text text-anchor="middle" x="398.6" y="-172.9" font-family="Times,serif" font-size="12.00">6</text>
# </g>
# <!-- 3&#45;&gt;6 -->
# <g id="edge8" class="edge">
# <title>3&#45;&gt;6</title>
# <path fill="none" stroke="black" d="M330.6,-166.43C340.91,-167.9 354.37,-169.82 366.53,-171.56"/>
# <polygon fill="black" stroke="black" points="366.36,-175.07 376.76,-173.02 367.35,-168.14 366.36,-175.07"/>
# <text text-anchor="middle" x="353.6" y="-174.8" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 7 -->
# <g id="node8" class="node">
# <title>7</title>
# <ellipse fill="none" stroke="black" cx="398.6" cy="-100" rx="18" ry="18"/>
# <text text-anchor="middle" x="398.6" y="-96.9" font-family="Times,serif" font-size="12.00">7</text>
# </g>
# <!-- 3&#45;&gt;7 -->
# <g id="edge9" class="edge">
# <title>3&#45;&gt;7</title>
# <path fill="none" stroke="black" d="M317.98,-146.7C322.78,-131.72 332.09,-110.94 348.6,-101 355.04,-97.12 362.87,-95.8 370.37,-95.74"/>
# <polygon fill="black" stroke="black" points="370.37,-99.24 380.56,-96.34 370.79,-92.25 370.37,-99.24"/>
# <text text-anchor="middle" x="353.6" y="-104.8" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 4&#45;&gt;6 -->
# <g id="edge10" class="edge">
# <title>4&#45;&gt;6</title>
# <path fill="none" stroke="black" d="M329.05,-264.04C338.38,-258.69 350.08,-251 358.6,-242 368.88,-231.14 377.65,-217.1 384.26,-204.76"/>
# <polygon fill="black" stroke="black" points="387.43,-206.24 388.87,-195.74 381.2,-203.05 387.43,-206.24"/>
# <text text-anchor="middle" x="353.6" y="-254.8" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 8 -->
# <g id="node9" class="node">
# <title>8</title>
# <ellipse fill="none" stroke="black" cx="398.6" cy="-302" rx="18" ry="18"/>
# <text text-anchor="middle" x="398.6" y="-298.9" font-family="Times,serif" font-size="12.00">8</text>
# </g>
# <!-- 4&#45;&gt;8 -->
# <g id="edge11" class="edge">
# <title>4&#45;&gt;8</title>
# <path fill="none" stroke="black" d="M329.8,-277.78C341.65,-282.02 357.98,-287.85 371.64,-292.73"/>
# <polygon fill="black" stroke="black" points="370.86,-296.17 381.45,-296.23 373.21,-289.57 370.86,-296.17"/>
# <text text-anchor="middle" x="353.6" y="-291.8" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 9 -->
# <g id="node10" class="node">
# <title>9</title>
# <ellipse fill="none" stroke="black" cx="398.6" cy="-41" rx="18" ry="18"/>
# <text text-anchor="middle" x="398.6" y="-37.9" font-family="Times,serif" font-size="12.00">9</text>
# </g>
# <!-- 5&#45;&gt;9 -->
# <g id="edge12" class="edge">
# <title>5&#45;&gt;9</title>
# <path fill="none" stroke="black" d="M323.47,-203.44C325.96,-199.49 328.51,-195.16 330.6,-191 343.27,-165.87 363.7,-98.01 376.6,-73 378.15,-69.99 379.92,-66.91 381.76,-63.9"/>
# <polygon fill="black" stroke="black" points="384.85,-65.57 387.32,-55.27 378.96,-61.78 384.85,-65.57"/>
# <text text-anchor="middle" x="353.6" y="-147.8" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 10 -->
# <g id="node11" class="node">
# <title>10</title>
# <ellipse fill="none" stroke="black" cx="458.3" cy="-270" rx="19.9" ry="19.9"/>
# <text text-anchor="middle" x="458.3" y="-266.9" font-family="Times,serif" font-size="12.00">10</text>
# </g>
# <!-- 5&#45;&gt;10 -->
# <g id="edge13" class="edge">
# <title>5&#45;&gt;10</title>
# <path fill="none" stroke="black" d="M330.95,-218.58C339.42,-219.2

# %% [markdown]
# ## 2. Entiers non décomposables
#
# L'opérateur de négation permet de trouver les entiers non représentables.

# %%
def nodecomp "~ $decomp(n)":
# Out:
# ~decomp(n)):14 states - 0ms
# Total computation time: 3ms.

# %%
%showme nodecomp
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="669pt" height="309pt"
#  viewBox="0.00 0.00 668.79 308.70" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 304.7)">
# <title>G</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-304.7 664.79,-304.7 664.79,4 -4,4"/>
# <text text-anchor="middle" x="330.4" y="-7.8" font-family="Times,serif" font-size="14.00">(n): ~ $decomp(n)</text>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="black" cx="58.6" cy="-108" rx="18" ry="18"/>
# <text text-anchor="middle" x="58.6" y="-104.9" font-family="Times,serif" font-size="12.00">0</text>
# </g>
# <!-- 0&#45;&gt;0 -->
# <g id="edge2" class="edge">
# <title>0&#45;&gt;0</title>
# <path fill="none" stroke="black" d="M52.22,-125.04C50.92,-134.86 53.05,-144 58.6,-144 62.07,-144 64.2,-140.43 65,-135.35"/>
# <polygon fill="black" stroke="black" points="68.5,-135.03 64.98,-125.04 61.5,-135.04 68.5,-135.03"/>
# <text text-anchor="middle" x="58.6" y="-147.8" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="black" cx="144.6" cy="-108" rx="18" ry="18"/>
# <ellipse fill="none" stroke="black" cx="144.6" cy="-108" rx="22" ry="22"/>
# <text text-anchor="middle" x="144.6" y="-104.9" font-family="Times,serif" font-size="12.00">1</text>
# </g>
# <!-- 0&#45;&gt;1 -->
# <g id="edge3" class="edge">
# <title>0&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M77,-108C87.19,-108 100.35,-108 112.28,-108"/>
# <polygon fill="black" stroke="black" points="112.34,-111.5 122.34,-108 112.34,-104.5 112.34,-111.5"/>
# <text text-anchor="middle" x="99.6" y="-111.8" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="black" cx="234.6" cy="-150" rx="18" ry="18"/>
# <ellipse fill="none" stroke="black" cx="234.6" cy="-150" rx="22" ry="22"/>
# <text text-anchor="middle" x="234.6" y="-146.9" font-family="Times,serif" font-size="12.00">2</text>
# </g>
# <!-- 1&#45;&gt;2 -->
# <g id="edge4" class="edge">
# <title>1&#45;&gt;2</title>
# <path fill="none" stroke="black" d="M164.69,-117.11C176.57,-122.78 192.06,-130.17 205.34,-136.51"/>
# <polygon fill="black" stroke="black" points="204.01,-139.76 214.54,-140.9 207.03,-133.44 204.01,-139.76"/>
# <text text-anchor="middle" x="189.6" y="-134.8" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 3 -->
# <g id="node4" class="node">
# <title>3</title>
# <ellipse fill="none" stroke="black" cx="324.6" cy="-88" rx="18" ry="18"/>
# <ellipse fill="none" stroke="black" cx="324.6" cy="-88" rx="22" ry="22"/>
# <text text-anchor="middle" x="324.6" y="-84.9" font-family="Times,serif" font-size="12.00">3</text>
# </g>
# <!-- 1&#45;&gt;3 -->
# <g id="edge5" class="edge">
# <title>1&#45;&gt;3</title>
# <path fill="none" stroke="black" d="M166.72,-105.63C197.9,-102.12 256.44,-95.55 292.53,-91.49"/>
# <polygon fill="black" stroke="black" points="292.96,-94.96 302.51,-90.37 292.18,-88.01 292.96,-94.96"/>
# <text text-anchor="middle" x="234.6" y="-104.8" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 4 -->
# <g id="node5" class="node">
# <title>4</title>
# <ellipse fill="none" stroke="black" cx="324.6" cy="-150" rx="18" ry="18"/>
# <ellipse fill="none" stroke="black" cx="324.6" cy="-150" rx="22" ry="22"/>
# <text text-anchor="middle" x="324.6" y="-146.9" font-family="Times,serif" font-size="12.00">4</text>
# </g>
# <!-- 2&#45;&gt;4 -->
# <g id="edge6" class="edge">
# <title>2&#45;&gt;4</title>
# <path fill="none" stroke="black" d="M256.9,-150C267.5,-150 280.51,-150 292.21,-150"/>
# <polygon fill="black" stroke="black" points="292.49,-153.5 302.49,-150 292.49,-146.5 292.49,-153.5"/>
# <text text-anchor="middle" x="279.6" y="-153.8" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 5 -->
# <g id="node6" class="node">
# <title>5</title>
# <ellipse fill="none" stroke="black" cx="324.6" cy="-212" rx="18" ry="18"/>
# <ellipse fill="none" stroke="black" cx="324.6" cy="-212" rx="22" ry="22"/>
# <text text-anchor="middle" x="324.6" y="-208.9" font-family="Times,serif" font-size="12.00">5</text>
# </g>
# <!-- 2&#45;&gt;5 -->
# <g id="edge7" class="edge">
# <title>2&#45;&gt;5</title>
# <path fill="none" stroke="black" d="M252.99,-162.25C265.76,-171.25 283.33,-183.63 297.75,-193.79"/>
# <polygon fill="black" stroke="black" points="296.06,-196.88 306.25,-199.78 300.09,-191.16 296.06,-196.88"/>
# <text text-anchor="middle" x="279.6" y="-185.8" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 6 -->
# <g id="node7" class="node">
# <title>6</title>
# <ellipse fill="none" stroke="black" cx="414.6" cy="-41" rx="18" ry="18"/>
# <text text-anchor="middle" x="414.6" y="-37.9" font-family="Times,serif" font-size="12.00">6</text>
# </g>
# <!-- 3&#45;&gt;6 -->
# <g id="edge8" class="edge">
# <title>3&#45;&gt;6</title>
# <path fill="none" stroke="black" d="M344.26,-78.03C357.38,-71.03 375.06,-61.59 389.28,-53.99"/>
# <polygon fill="black" stroke="black" points="391.3,-56.88 398.47,-49.08 388,-50.7 391.3,-56.88"/>
# <text text-anchor="middle" x="369.6" y="-69.8" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 7 -->
# <g id="node8" class="node">
# <title>7</title>
# <ellipse fill="none" stroke="black" cx="414.6" cy="-99" rx="18" ry="18"/>
# <ellipse fill="none" stroke="black" cx="414.6" cy="-99" rx="22" ry="22"/>
# <text text-anchor="middle" x="414.6" y="-95.9" font-family="Times,serif" font-size="12.00">7</text>
# </g>
# <!-- 3&#45;&gt;7 -->
# <g id="edge9" class="edge">
# <title>3&#45;&gt;7</title>
# <path fill="none" stroke="black" d="M346.65,-88.64C355.33,-89.07 365.48,-89.79 374.6,-91 377.33,-91.36 380.16,-91.81 382.99,-92.3"/>
# <polygon fill="black" stroke="black" points="382.57,-95.78 393.05,-94.22 383.88,-88.9 382.57,-95.78"/>
# <text text-anchor="middle" x="369.6" y="-94.8" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 4&#45;&gt;6 -->
# <g id="edge10" class="edge">
# <title>4&#45;&gt;6</title>
# <path fill="none" stroke="black" d="M343.07,-137.17C353.22,-129.08 365.71,-117.92 374.6,-106 385.77,-91.02 382.8,-83.92 392.6,-68 393.67,-66.26 394.84,-64.49 396.05,-62.74"/>
# <polygon fill="black" stroke="black" points="399.16,-64.43 402.31,-54.32 393.54,-60.26 399.16,-64.43"/>
# <text text-anchor="middle" x="369.6" y="-120.8" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 8 -->
# <g id="node9" class="node">
# <title>8</title>
# <ellipse fill="none" stroke="black" cx="414.6" cy="-223" rx="18" ry="18"/>
# <ellipse fill="none" stroke="black" cx="414.6" cy="-223" rx="22" ry="22"/>
# <text text-anchor="middle" x="414.6" y="-219.9" font-family="Times,serif" font-size="12.00">8</text>
# </g>
# <!-- 4&#45;&gt;8 -->
# <g id="edge11" class="edge">
# <title>4&#45;&gt;8</title>
# <path fill="none" stroke="black" d="M345.99,-155.52C355.34,-158.73 366.19,-163.45 374.6,-170 377.38,-172.17 386.56,-184.58 395.31,-196.85"/>
# <polygon fill="black" stroke="black" points="392.58,-199.05 401.22,-205.19 398.29,-195 392.58,-199.05"/>
# <text text-anchor="middle" x="369.6" y="-173.8" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 9 -->
# <g id="node10" class="node">
# <title>9</title>
# <ellipse fill="none" stroke="black" cx="414.6" cy="-161" rx="18" ry="18"/>
# <ellipse fill="none" stroke="black" cx="414.6" cy="-161" rx="22" ry="22"/>
# <text text-anchor="middle" x="414.6" y="-157.9" font-family="Times,serif" font-size="12.00">9</text>
# </g>
# <!-- 5&#45;&gt;9 -->
# <g id="edge12" class="edge">
# <title>5&#45;&gt;9</title>
# <path fill="none" stroke="black" d="M345.1,-203.84C354.26,-199.76 365.2,-194.52 374.6,-189 379.16,-186.33 383.85,-183.26 388.32,-180.16"/>
# <polygon fill="black" stroke="black" points="390.49,-182.92 396.59,-174.25 386.42,-177.22 390.49,-182.92"/>
# <text text-anchor="middle" x="369.6"

# %% [markdown]
# On observe que cet automate est un DAG (si on met de côté la bouclette de 0 sur l'état initial). Il n'existe qu'on nombre fini d'entiers non décomposables. Trouvons le plus grand !

# %%
eval chicken "~ $decomp(n) & Am m>n => $decomp(m)":
# Out:
# ~decomp(n)):14 states - 0ms
#  m>n:2 states - 0ms
#   (m>n=>decomp(m))):24 states - 3ms
#    (A m (m>n=>decomp(m)))):11 states - 2ms
#     (~decomp(n))&(A m (m>n=>decomp(m))))):7 states - 0ms
# Total computation time: 7ms.

# %%
%showme chicken
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="585pt" height="104pt"
#  viewBox="0.00 0.00 584.60 104.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 100)">
# <title>G</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-100 580.6,-100 580.6,4 -4,4"/>
# <text text-anchor="middle" x="288.3" y="-7.8" font-family="Times,serif" font-size="14.00">(n): ~ $decomp(n) &amp; Am m&gt;n =&gt; $decomp(m)</text>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="black" cx="58.6" cy="-45" rx="18" ry="18"/>
# <text text-anchor="middle" x="58.6" y="-41.9" font-family="Times,serif" font-size="12.00">0</text>
# </g>
# <!-- 0&#45;&gt;0 -->
# <g id="edge2" class="edge">
# <title>0&#45;&gt;0</title>
# <path fill="none" stroke="black" d="M52.22,-62.04C50.92,-71.86 53.05,-81 58.6,-81 62.07,-81 64.2,-77.43 65,-72.35"/>
# <polygon fill="black" stroke="black" points="68.5,-72.03 64.98,-62.04 61.5,-72.04 68.5,-72.03"/>
# <text text-anchor="middle" x="58.6" y="-84.8" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="black" cx="140.6" cy="-45" rx="18" ry="18"/>
# <text text-anchor="middle" x="140.6" y="-41.9" font-family="Times,serif" font-size="12.00">1</text>
# </g>
# <!-- 0&#45;&gt;1 -->
# <g id="edge3" class="edge">
# <title>0&#45;&gt;1</title>
# <path fill="none" stroke="black" d="M76.96,-45C87.3,-45 100.66,-45 112.38,-45"/>
# <polygon fill="black" stroke="black" points="112.55,-48.5 122.55,-45 112.55,-41.5 112.55,-48.5"/>
# <text text-anchor="middle" x="99.6" y="-48.8" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="black" cx="222.6" cy="-45" rx="18" ry="18"/>
# <text text-anchor="middle" x="222.6" y="-41.9" font-family="Times,serif" font-size="12.00">2</text>
# </g>
# <!-- 1&#45;&gt;2 -->
# <g id="edge4" class="edge">
# <title>1&#45;&gt;2</title>
# <path fill="none" stroke="black" d="M158.96,-45C169.3,-45 182.66,-45 194.38,-45"/>
# <polygon fill="black" stroke="black" points="194.55,-48.5 204.55,-45 194.55,-41.5 194.55,-48.5"/>
# <text text-anchor="middle" x="181.6" y="-48.8" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 3 -->
# <g id="node4" class="node">
# <title>3</title>
# <ellipse fill="none" stroke="black" cx="304.6" cy="-45" rx="18" ry="18"/>
# <text text-anchor="middle" x="304.6" y="-41.9" font-family="Times,serif" font-size="12.00">3</text>
# </g>
# <!-- 2&#45;&gt;3 -->
# <g id="edge5" class="edge">
# <title>2&#45;&gt;3</title>
# <path fill="none" stroke="black" d="M240.96,-45C251.3,-45 264.66,-45 276.38,-45"/>
# <polygon fill="black" stroke="black" points="276.55,-48.5 286.55,-45 276.55,-41.5 276.55,-48.5"/>
# <text text-anchor="middle" x="263.6" y="-48.8" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 4 -->
# <g id="node5" class="node">
# <title>4</title>
# <ellipse fill="none" stroke="black" cx="386.6" cy="-45" rx="18" ry="18"/>
# <text text-anchor="middle" x="386.6" y="-41.9" font-family="Times,serif" font-size="12.00">4</text>
# </g>
# <!-- 3&#45;&gt;4 -->
# <g id="edge6" class="edge">
# <title>3&#45;&gt;4</title>
# <path fill="none" stroke="black" d="M322.96,-45C333.3,-45 346.66,-45 358.38,-45"/>
# <polygon fill="black" stroke="black" points="358.55,-48.5 368.55,-45 358.55,-41.5 358.55,-48.5"/>
# <text text-anchor="middle" x="345.6" y="-48.8" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 5 -->
# <g id="node6" class="node">
# <title>5</title>
# <ellipse fill="none" stroke="black" cx="468.6" cy="-45" rx="18" ry="18"/>
# <text text-anchor="middle" x="468.6" y="-41.9" font-family="Times,serif" font-size="12.00">5</text>
# </g>
# <!-- 4&#45;&gt;5 -->
# <g id="edge7" class="edge">
# <title>4&#45;&gt;5</title>
# <path fill="none" stroke="black" d="M404.96,-45C415.3,-45 428.66,-45 440.38,-45"/>
# <polygon fill="black" stroke="black" points="440.55,-48.5 450.55,-45 440.55,-41.5 440.55,-48.5"/>
# <text text-anchor="middle" x="427.6" y="-48.8" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 6 -->
# <g id="node7" class="node">
# <title>6</title>
# <ellipse fill="none" stroke="black" cx="554.6" cy="-45" rx="18" ry="18"/>
# <ellipse fill="none" stroke="black" cx="554.6" cy="-45" rx="22" ry="22"/>
# <text text-anchor="middle" x="554.6" y="-41.9" font-family="Times,serif" font-size="12.00">6</text>
# </g>
# <!-- 5&#45;&gt;6 -->
# <g id="edge8" class="edge">
# <title>5&#45;&gt;6</title>
# <path fill="none" stroke="black" d="M487,-45C497.19,-45 510.35,-45 522.28,-45"/>
# <polygon fill="black" stroke="black" points="522.34,-48.5 532.34,-45 522.34,-41.5 522.34,-48.5"/>
# <text text-anchor="middle" x="509.6" y="-48.8" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- qi -->
# <g id="node8" class="node">
# <title>qi</title>
# <ellipse fill="black" stroke="black" cx="1.8" cy="-45" rx="1.8" ry="1.8"/>
# </g>
# <!-- qi&#45;&gt;0 -->
# <g id="edge1" class="edge">
# <title>qi&#45;&gt;0</title>
# <path fill="none" stroke="black" d="M3.75,-45C7.11,-45 18.87,-45 30.55,-45"/>
# <polygon fill="black" stroke="black" points="30.58,-48.5 40.58,-45 30.58,-41.5 30.58,-48.5"/>
# </g>
# <!-- \n -->
# <g id="node9" class="node">
# <title>\n</title>
# <ellipse fill="black" stroke="black" cx="1.8" cy="-67" rx="1.8" ry="1.8"/>
# </g>
# </g>
# </svg>

# %%
eval tadam "~$decomp(43) & An n>43 => $decomp(n)":
# Out:
# ~decomp(43)):1 states - 0ms
#  n>43:9 states - 1ms
#   (n>43=>decomp(n))):1 states - 1ms
#    (A n (n>43=>decomp(n)))):1 states - 0ms
#     (~decomp(43))&(A n (n>43=>decomp(n))))):0 states - 0ms
# Total computation time: 5ms.
# ____
# TRUE

# %% [markdown]
# La réponse est 43 !
